# %%
x = 123456789
temp = x
count = 1
while temp > 10:
    count += 1
    temp = temp //10
print(count)

# %%
from math import log
x = 123456789
temp = x
y = log(temp, 10)
print(y)

z = int(y) + 1
print(z)
