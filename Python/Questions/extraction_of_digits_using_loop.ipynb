# %%
x = 1234
temp = x # you will have to assign the value of temp to x here itself
while temp > 0:
    # temp = x -> i was earlier making this mistake of assigning temp to x again so it was resulting in an never ending loop
    y = temp % 10
    print(y)
    temp = temp // 10
