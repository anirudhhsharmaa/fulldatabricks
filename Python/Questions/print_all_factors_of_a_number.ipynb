# %%
x = 19

a = [] #empty list

for i in range(1, x + 1):
    if x % i == 0:
        a.append(i)
print(a)

# %%
x = 15

a = [] #empty list

i = 1
while i <= x:
    if x % i == 0:
        a.append(i)
    i += 1
print(a)
